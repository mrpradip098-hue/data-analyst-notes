# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_excel("/content/Washington Crimes Dataset - March 2025 (2).xlsx")
# Out:
#      ANC   LATITUDE  Lat_Rounded                                       BLOCK  \
# 0     6E  38.903732       38.904              100 - 199 block of l street ne
# 1     2C  38.903743       38.904              18th street nw and l street nw
# 2     1B  38.917236       38.917          2000 - 2099 block of 8th street nw
# 3     5D  38.909405       38.909          1300 - 1399 block of 5th street ne
# 4     1D  38.930801       38.931       1600 - 1665 block of lamont street nw
# ...   ..        ...          ...                                         ...
# 3862  3F  38.950204       38.950  4600 - 4699 block of connecticut avenue nw
# 3863  6A  38.896725       38.897            500 - 599 block of 8th street ne
# 3864  6E  38.907643       38.908   1200 - 1499 block of north capitol street
# 3865  1C  38.922329       38.922     1800 - 1899 block of biltmore street nw
# 3866  1C  38.918309       38.918      1701 - 1710 block of florida avenue nw
#
# ...
