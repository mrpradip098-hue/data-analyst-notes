# %%
 # load all the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_excel("/content/marketing_data (1).xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2240 non-null   int64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Month                2240 non-null   object
#  8   Day                  2240 non-null   int64
#  9   Year                 2240 non-null   int64
#  10  Recency              2240 non-null   int64
#  11  MntWines             2240 non-null   int64
#  12  MntFruits            2240 non-null   int64
#  13  MntMeatProducts      2240 non-null   int64
#  14  MntFishProducts      2240 non-null   int64
# ...

# %%
df["Age"]= 2025-df["Year_Birth"]

# %%
df["Age_Group"]= pd.cut(df["Age"],
                        bins =[0,18,40,60,123],
                        labels=["Child","Adult","Senior","Old Age"])

# %%
df["Total_Spending"]=(df['MntWines']+df['MntFruits']+df['MntMeatProducts']+
                      df['MntFishProducts']+ df['MntSweetProducts']+df['MntGoldProds'])

# %%
df["Total_Reg_Purchase"]= (df['NumWebPurchases']+df['NumCatalogPurchases']+
                           df['NumStorePurchases'])

# %%
df["Purchases_Type"]= np.where(df['NumDealsPurchases']>0,"Deal","Regular")

# %%
#Qu1

# %%
df.size
# Out:
# 78400

# %%
# by Education

# %%
df['Education'].unique()
# Out:
# array(['Graduation', 'PhD', '2n Cycle', 'Master', 'Basic'], dtype=object)

# %%
df['Education'].value_counts()
# Out:
# Education
# Graduation    1127
# PhD            486
# Master         370
# 2n Cycle       203
# Basic           54
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df,x="Education")
plt.title("Customer by Education Level")
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Graduation'),
#   Text(1, 0, 'PhD'),
#   Text(2, 0, '2n Cycle'),
#   Text(3, 0, 'Master'),
#   Text(4, 0, 'Basic')])

# %%
#Q2

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df,x="Marital_Status")
plt.title("Customer by Marital_Status ")
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Divorced'),
#   Text(1, 0, 'Single'),
#   Text(2, 0, 'Married'),
#   Text(3, 0, 'Together'),
#   Text(4, 0, 'Widow')])

# %%
#Q3

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df,x="Country")
plt.title("Customer by Country ")
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'SP'),
#   Text(1, 0, 'CA'),
#   Text(2, 0, 'US'),
#   Text(3, 0, 'AUS'),
#   Text(4, 0, 'GER'),
#   Text(5, 0, 'IND'),
#   Text(6, 0, 'SA'),
#   Text(7, 0, 'ME')])

# %%
#Q4

# %%
df.groupby("Education")[ ' Income ' ].mean()
# Out:
# Education
# 2n Cycle      46929.251232
# Basic         20306.259259
# Graduation    52205.800355
# Master        52202.432432
# PhD           55567.687243
# Name:  Income , dtype: float64

# %%
plt.figure(figsize=(5,3))
sns.barplot(data=df, x= "Education",y = ' Income ',ci=False)
# Out:
# /tmp/ipython-input-4109393925.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(data=df, x= "Education",y = ' Income ',ci=False)
# <Axes: xlabel='Education', ylabel=' Income '>

# %%
#Q5

# %%
df.groupby("Marital_Status")[ ' Income ' ].mean()
# Out:
# Marital_Status
# Divorced    52834.228448
# Married     51305.910880
# Single      50085.774127
# Together    52602.915517
# Widow       55748.025974
# Name:  Income , dtype: float64

# %%
plt.figure(figsize=(5,3))
sns.barplot(data=df, x= "Marital_Status",y = ' Income ',ci=False)
# Out:
# /tmp/ipython-input-3368095174.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(data=df, x= "Marital_Status",y = ' Income ',ci=False)
# <Axes: xlabel='Marital_Status', ylabel=' Income '>

# %%
#Q6

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ',
#        'Kidhome', 'Teenhome', 'Month', 'Day', 'Year', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country', 'Age', 'Age_Group',
#        'Total_Spending', 'Total_Reg_Purchase', 'Purchases_Type'],
#       dtype='object')

# %%
df['Kidhome'].unique()
# Out:
# array([0, 1, 2])

# %%
df['Kidhome'].value_counts()
# Out:
# Kidhome
# 0    1293
# 1     899
# 2      48
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,4))
sns.countplot(data=df,x="Kidhome")
plt.title("Distribution ")
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2], [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2')])

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ',
#        'Kidhome', 'Teenhome', 'Month', 'Day', 'Year', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country', 'Age', 'Age_Group',
#        'Total_Spending', 'Total_Reg_Purchase', 'Purchases_Type'],
#       dtype='object')

# %%
categories = {
    "wines":df['MntWines'].sum(),
    "Fruits":df['MntFruits'].sum(),
    "meat":df['MntMeatProducts'].sum(),
    "Fish":df['MntFishProducts'].sum(),
    "sweet":df['MntSweetProducts'].sum(),
    "gold":df['MntGoldProds'].sum()
    }

# %%
categories
# Out:
# {'wines': np.int64(680816),
#  'Fruits': np.int64(58917),
#  'meat': np.int64(373968),
#  'Fish': np.int64(84057),
#  'sweet': np.int64(60621),
#  'gold': np.int64(98609)}

# %%
Q8 =pd.Series(categories)

# %%
Q8
# Out:
# wines     680816
# Fruits     58917
# meat      373968
# Fish       84057
# sweet      60621
# gold       98609
# dtype: int64

# %%
sns.barplot(x=Q8.index,y=Q8.values)
# Out:
# <Axes: xlabel='None'>

# %%
#Q9

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ',
#        'Kidhome', 'Teenhome', 'Month', 'Day', 'Year', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country', 'Age', 'Age_Group',
#        'Total_Spending', 'Total_Reg_Purchase', 'Purchases_Type'],
#       dtype='object')

# %%
categories = {
    "Deals":df['NumDealsPurchases'].sum(),
    "Web":df['NumWebPurchases'].sum(),
    "Catalog":df['NumCatalogPurchases'].sum(),
    "Store":df['NumStorePurchases'].sum(),
    "WebVisits":df['NumWebVisitsMonth'].sum(),
}

# %%
categories
# Out:
# {'Deals': np.int64(5208),
#  'Web': np.int64(9150),
#  'Catalog': np.int64(5963),
#  'Store': np.int64(12970),
#  'WebVisits': np.int64(11909)}

# %%
Q9 =pd.Series(categories)

# %%
Q9
# Out:
# Deals         5208
# Web           9150
# Catalog       5963
# Store        12970
# WebVisits    11909
# dtype: int64

# %%
sns.barplot(x=Q9.index,y=Q9.values)
# Out:
# <Axes: xlabel='None'>

# %%
#Q11

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ',
#        'Kidhome', 'Teenhome', 'Month', 'Day', 'Year', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country', 'Age', 'Age_Group',
#        'Total_Spending', 'Total_Reg_Purchase', 'Purchases_Type'],
#       dtype='object')

# %%
camp=['AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
       'AcceptedCmp2']

# %%
Q12=df[camp].mean()*100

# %%
Q12
# Out:
# AcceptedCmp3    7.276786
# AcceptedCmp4    7.455357
# AcceptedCmp5    7.276786
# AcceptedCmp1    6.428571
# AcceptedCmp2    1.339286
# dtype: float64

# %%
sns.barplot(x=Q12.index,y=Q12.values)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'AcceptedCmp3'),
#   Text(1, 0, 'AcceptedCmp4'),
#   Text(2, 0, 'AcceptedCmp5'),
#   Text(3, 0, 'AcceptedCmp1'),
#   Text(4, 0, 'AcceptedCmp2')])

# %%
sns.scatterplot(data=df,x=' Income ',y='Total_Spending')
# Out:
# <Axes: xlabel=' Income ', ylabel='Total_Spending'>
